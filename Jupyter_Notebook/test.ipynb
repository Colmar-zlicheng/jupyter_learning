# %%
import numpy as np

# %%
a = np.array([1,2,3])

# %%
print(a)
# Out:
# [1 2 3]

# %%
# %load test.py
import numpy as np

a = np.array([1, 2, 3])

print(a)
# Out:
# [1 2 3]

# %%
# %run test.py
# Out:
# [1 2 3]
